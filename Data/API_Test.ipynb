# %%
from nba_api.stats.endpoints import playercareerstats, leaguegamefinder
from nba_api.stats.static import teams, players

import pandas as pd

pd.set_option("display.max_columns", 50)
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
career = playercareerstats.PlayerCareerStats(player_id='203076')
print(len(career.get_data_frames()))
# Out:
# 10

# %%
career.get_data_frames()[0]  # year by year
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
#
#    GP  GS     MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 0  64  60  1846.0  349   676   0.516     0     6    0.000  169  225   0.751
# 1  67  66  2358.0  522  1005   0.519     2     9    0.222  348  440   0.791
# ...

# %%
career.get_data_frames()[1]  # career total
# Out:
#    PLAYER_ID LEAGUE_ID  Team_ID   GP   GS      MIN   FGM   FGA    FG_PCT  \
# 0     203076        00        0  521  516  17997.0  4661  9024  0.516511
#
#    FG3M  FG3A  FG3_PCT   FTM   FTA    FT_PCT  OREB  DREB   REB   AST  STL  \
# 0   246   770  0.31948  2958  3691  0.801408  1332  4090  5422  1154  721
#
#     BLK   TOV    PF    PTS
# 0  1255  1004  1244  12526

# %%
career.get_data_frames()[2]  # year by year playoff
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2014-15        00  1610612740               NOP        22.0
# 1     203076   2017-18        00  1610612740               NOP        25.0
#
#    GP  GS    MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 0   4   4  172.0   47   87    0.54     0     2    0.000   32   36   0.889
# 1   9   9  358.0  106  204    0.52     6    22    0.273   53   64   0.828
#
#    OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0     9    35   44    8    5   12   13  12  126
# 1    24    97  121   15   18   21   23  30  271

# %%
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
nba_teams[:3]
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %%
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_players[:5]
# Out:
# Number of players fetched: 4501
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False}]

# %%
[player for player in nba_players if player['full_name'] == "Russell Westbrook"]
# Out:
# [{'id': 201566,
#   'full_name': 'Russell Westbrook',
#   'first_name': 'Russell',
#   'last_name': 'Westbrook',
#   'is_active': True}]

# %%
players_df = pd.DataFrame(nba_players)
players_df = players_df.set_index("id")
players_df
# Out:
#                    full_name first_name     last_name  is_active
# id
# 76001         Alaa Abdelnaby       Alaa     Abdelnaby      False
# 76002        Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 76003    Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 51        Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 1505       Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False
# ...                      ...        ...           ...        ...
# 1627790           Ante Zizic       Ante         Zizic       True
# 78647               Jim Zoet        Jim          Zoet      False
# 78648              Bill Zopf       Bill          Zopf      False
# 1627826          Ivica Zubac      Ivica         Zubac       True
# 78650             Matt Zunic       Matt         Zunic      False
#
# [4501 rows x 4 columns]

# %%
nba_teams
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
teams = [t["full_name"] for t in nba_teams]
teams
# Out:
# ['Atlanta Hawks',
#  'Boston Celtics',
#  'Cleveland Cavaliers',
#  'New Orleans Pelicans',
#  'Chicago Bulls',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Los Angeles Clippers',
#  'Los Angeles Lakers',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Minnesota Timberwolves',
#  'Brooklyn Nets',
#  'New York Knicks',
#  'Orlando Magic',
#  'Indiana Pacers',
#  'Philadelphia 76ers',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Oklahoma City Thunder',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Memphis Grizzlies',
#  'Washington Wizards',
#  'Detroit Pistons',
#  'Charlotte Hornets']

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable="2018-19", season_type_nullable="Regular Season")
games = gamefinder.get_data_frames()[0]
games = games.loc[games.TEAM_NAME.isin(teams)]

games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0        22018  1610612749               MIL        Milwaukee Bucks
# 1        22018  1610612737               ATL          Atlanta Hawks
# 2        22018  1610612760               OKC  Oklahoma City Thunder
# 3        22018  1610612766               CHA      Charlotte Hornets
# 4        22018  1610612744               GSW  Golden State Warriors
# ...        ...         ...               ...                    ...
# 4303     22018  1610612763               MEM      Memphis Grizzlies
# 4304     22018  1610612759               SAS      San Antonio Spurs
# 4305     22018  1610612762               UTA              Utah Jazz
# 4306     22018  1610612758               SAC       Sacramento Kings
# 4307     22018  1610612737               ATL          Atlanta Hawks
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  \
# 0     0021801226  2019-04-10  MIL vs. OKC  L  241  116   43  100   0.430
# ...

# %%
# Out:
# 0021800254    2
# 0021801200    2
# 0021801020    2
# 0021800496    2
# 0021800952    2
#              ..
# 0021801095    1
# 0021800947    1
# 1521800029    1
# 0021800315    1
# 0021800919    1
# Name: GAME_ID, Length: 1324, dtype: int64
